# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA Paisabazaar Banking Fraud Analysis
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**  Atharv Gajanan Shete

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Paisabazaar is a financial services company that assists customers in finding and applying for various banking and credit products. An integral part of their service is assessing the creditworthiness of individuals, which is crucial for both loan approval and risk management. The credit score of a person is a significant metric used by financial institutions to determine the likelihood that an individual will repay their loans or credit balances. Accurate classification of credit scores can help Paisabazaar enhance their credit assessment processes, reduce the risk of loan defaults, and offer personalized financial advice to their customers.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Link:- https://github.com/AtharvShete2610/Paisa-Bazar-EDA.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Paisabazaar Banking Fraud Analysis

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To analyze customer transaction data from Paisabazaar in order to identify patterns, trends, and anomalies that can help in detecting and preventing potential banking fraud, thereby improving financial security and customer trust.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Load Dataset
data = pd.read_csv('dataset.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape
# Out:
# (100000, 28)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
data.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(data.isnull(),cbar=True)
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# In this dataset there are total 100000 rows and 28 columns. There is 0 non null values and also 0 duplicate records.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# Dataset Describe
data.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ![Data Description.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
data.nunique()
# Out:
# ID                          100000
# Customer_ID                  12500
# Month                            8
# Name                         10128
# Age                             43
# SSN                          12500
# Occupation                      15
# Annual_Income                12488
# Monthly_Inhand_Salary        13241
# Num_Bank_Accounts               12
# Num_Credit_Card                 12
# Interest_Rate                   34
# Num_of_Loan                     10
# Type_of_Loan                  6261
# Delay_from_due_date             63
# Num_of_Delayed_Payment          26
# Changed_Credit_Limit          3452
# Num_Credit_Inquiries            18
# Credit_Mix                       3
# Outstanding_Debt             12203
# Credit_Utilization_Ratio    100000
# Credit_History_Age             404
# Payment_of_Min_Amount            3
# Total_EMI_per_month          11890
# Amount_invested_monthly      12261
# Payment_Behaviour                6
# Monthly_Balance              98494
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# If there are any duplictae value drop them
data.drop_duplicates(inplace=True)

# %%
# Cheking any null values
data.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I drop a duplicte record if any present and also check for null values but there is 0 not null values.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code (Histogram)
plt.figure(figsize=(8, 5))
sns.histplot(data['Age'], bins=30, kde=True, color='steelblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Histogram helps understand continuous variable distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of Paisabazaar’s customers are aged between 25 and 45, indicating a young and financially active user base. Very few customers are below 18 or above 50.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight helps in targeted fraud detection and personalized financial offerings for the core age group, improving model accuracy and user engagement.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code (Count Plot)
plt.figure(figsize=(10, 6))
sns.countplot(y='Occupation', data=data, order=data['Occupation'].value_counts().index, palette="Set2")
plt.title("Customer Occupations")
plt.xlabel("Count")
plt.ylabel("Occupation")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14100\4113151162.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Occupation', data=data, order=data['Occupation'].value_counts().index, palette="Set2")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Beacuse barplot Categorical variable analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that occupations are evenly distributed, with slight dominance by Lawyers, Engineers, and Architects. No single occupation overwhelmingly dominates, indicating a diverse customer base across professions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This diversity enables Paisabazaar to tailor financial products and fraud risk models for multiple professional segments, enhancing customer targeting and credit assessment accuracy.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code (Count Plot)
plt.figure(figsize=(6, 4))
sns.countplot(x='Credit_Score', data=data, palette='pastel')
plt.title('Credit Score Distribution')
plt.xlabel('Credit Score')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14100\3943692307.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Credit_Score', data=data, palette='pastel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Beacuse count plot gives quick categorical insight.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most customers fall under the Standard credit score category, followed by Poor and then Good. This suggests a majority have average creditworthiness, while fewer exhibit strong financial discipline.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This distribution can guide Paisabazaar to focus fraud detection and risk mitigation strategies on Standard and Poor score segments, who are more likely to default or be targeted for fraud.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code (Pie Chart)
data['Credit_Mix'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title("Credit Mix Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart is ideal Categorical proportions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most people (45.8%) have a Standard credit mix, followed by Good (30.4%) and Bad (23.8%). This means that while many customers have a balanced mix of credit types, a good number still have either excellent or poor credit variety.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Paisabazaar can use this to offer custom financial products—more responsible borrowers with good credit mix could get better loan offers, while those with poor mix may need credit counseling or stricter fraud checks.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code (Box Plot)
plt.figure(figsize=(10, 4))
sns.boxplot(x='Num_of_Delayed_Payment', data=data, color='salmon')
plt.title('Delayed Payments Distribution')
plt.xlabel('Number of Delays')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The boxplot is used for Checking outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot shows that most customers delay payments between 8 to 20 times, with the median around 14 delays. A few customers delay payments very little , and some delay more than 20 times.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A high number of delays increases the risk of loan default or fraud.
#
# Paisabazaar can flag users with frequent delays for closer monitoring or apply stricter credit rules.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code (Scatter Plot)
sns.scatterplot(x='Outstanding_Debt', y='Monthly_Balance', hue='Credit_Score', data=data)
plt.title('Outstanding Debt vs Monthly Balance')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is ideal for analyzing the relationship between two continuous numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Low outstanding debt is linked with higher monthly balances and better credit scores.
#
# As outstanding debt increases, especially beyond 2000, theres a clear rise in poor credit scores.
#
# Poor credit scores dominate when both debt is high and monthly balance is low.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Customers with high debt and low monthly balance are at a higher risk of default or fraud.
#
# This visualization helps Paisabazaar target financially stressed users for early intervention like risk assessment, counseling, or stricter loan approval.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code (Line Plot)
sns.lineplot(x='Age', y='Total_EMI_per_month', data=data)
plt.title('EMI per Month vs Age')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line plot is suitable for observing trends over a continuous variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Younger customers especially around age 18–20 tend to have higher EMIs, possibly due to new loans like education or personal loans.
#
# As age increases, the average EMI amount decreases, indicating fewer or smaller active loans in older age groups.
#
# The variability in EMI values also narrows down after age 40.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Younger customers are likely to carry higher financial liabilities, posing a moderate risk if income data isn't strong.
#
# Paisabazaar can use this insight to tailor loan offerings by age group, focusing on debt management plans for younger users.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code (Bar Plot)
sns.barplot(x='Occupation', y='Num_of_Loan', data=data)
plt.xticks(rotation=90)
plt.title('Average Number of Loans by Occupation')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is ideal when comparing the average value of a numerical column across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most occupations have an average of around 3.5 loans.
#
# Doctors and Lawyers appear to have a slightly higher number of loans, while Architects and Journalists are slightly lower.
#
# The overall variation across occupations is minimal, indicating a fairly uniform loan distribution.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Paisabazaar can conclude that occupation alone is not a strong differentiator in the number of loans held.
#
# Additional factors like income, age, or credit score should be combined with occupation for better risk profiling and fraud detection.

# %% [markdown]
# #### Chart - 9 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
selected_cols = ['Age','Annual_Income','Monthly_Inhand_Salary','Num_Bank_Accounts','Num_Credit_Card','Interest_Rate','Num_of_Loan','Delay_from_due_date','Num_of_Delayed_Payment','Outstanding_Debt','Credit_Utilization_Ratio','Credit_History_Age',
'Total_EMI_per_month','Amount_invested_monthly','Monthly_Balance']
important_data = data[selected_cols]

# Calculate correlation matrix
corr_matrix = important_data.corr()

# Plot heatmap
plt.figure(figsize=(14,10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Key Financial Features")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap of the correlation matrix is chosen to visually explore the relationships between numerical variables in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Income & Salary are strongly correlated, as expected.
#
# More Loans link with more credit cards, bank accounts, and outstanding debt.
#
# Higher Interest Rates and delays are tied to lower credit history age.
#
# Monthly Balance increases with in-hand salary and investments.
#
# Credit history has a negative link with loans and interest rates—riskier profiles.

# %% [markdown]
# #### Chart - 10 - Pair Plot

# %%
# Pair Plot visualization code
selected_cols = data[['Annual_Income','Num_of_Loan','Outstanding_Debt','Monthly_Balance','Credit_Score']]
sns.pairplot(data=selected_cols, hue='Credit_Score')
plt.suptitle("Pair Plot of Key Financial Metrics by Credit Score", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is chosen because it allows us to visually explore the relationships between multiple numerical variables in a single view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Good credit scores tend to cluster around higher monthly balances and lower outstanding debt.
#
# Poor credit scores are more frequent with higher debt and more loans.
#
# People with standard credit appear evenly spread but slightly concentrated in moderate income and debt ranges.
#
# Higher annual income is common among all groups, but poor scores still appear—suggesting income alone doesn’t ensure a good score.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. Customer Segmentation: Use patterns from EDA to segment customers by risk based on credit score, debt, and payment history. This allows for targeted monitoring and personalized financial strategies.
#
# 2. Early Fraud Detection: Build predictive models using key features like number of delayed payments, outstanding debt, and monthly balance to flag potentially fraudulent behavior early.
#
# 3. Improve Credit Risk Assessment: Leverage insights  to enhance the scoring system for more accurate loan approvals and risk-based pricing.
#
# 4. Financial Education: Promote awareness among customers with poor or standard credit scores by offering credit counseling and tools to manage loans and balances better.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis reveals strong patterns between financial behavior and credit scores. Key features like delayed payments, outstanding debt, and number of loans are crucial indicators of fraud risk. By leveraging these insights, Paisabazaar can enhance fraud detection, personalize credit offerings, and support better financial decision-making for its users.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
